# %% [markdown]
# # Exploratory Data Analysis (EDA) for Columns 33 to 47

# %%
import pandas as pd

# Load Excel data
file_path = "week2_all_features.xlsx"
df = pd.read_excel(file_path)

# Select only columns 33 to 47 (Python is 0-indexed, so 32:47+1)
df_selected = df.iloc[:, 32:47]

df_selected.head()
# Out:
#    Late_Applicant  Opportunity_Popularity  Popular_Opportunity  \
# 0               0                1.775924                    1
# 1               0                1.775924                    1
# 2               1                1.775924                    1
# 3               0                1.775924                    1
# 4               0                1.775924                    1
#
#      Age_Major_Combo        Country_Gender    Region_Opportunity  \
# 0  Young_Adult_Other       Pakistan_Female     South_Asia_Course
# 1   Young_Adult_Tech          India_Female     South_Asia_Course
# 2   Young_Adult_Tech    United States_Male  North_America_Course
# 3         Adult_Tech  United States_Female  North_America_Course
# 4   Young_Adult_Tech    United States_Male  North_America_Course
#
#    Engagement_Score Engagement_Level  Apply_vs_Start_Gap  \
# 0               1.0             High                -460
# 1               1.0             High                -300
# 2               0.6             High                -604
# 3               0.6             High                -549
# 4               1.0             High                -447
#
#    Applications_per_User  Unique_Categories_per_User  \
# 0                      1                           1
# 1                     14                           2
# 2                     17                           3
# 3                     13                           3
# 4                      1                           1
#
#              Region_AgeGroup  Applications_for_Opportunity  \
# 0     South_Asia_Young_Adult                          1423
# 1     South_Asia_Young_Adult                          1423
# 2  North_America_Young_Adult                          1423
# 3        North_America_Adult                          1423
# 4  North_America_Young_Adult                          1423
#
#    Region_Normalized_Applications  User_Success_Rate
# 0                             1.0           1.000000
# 1                             1.0           0.142857
# 2                             1.0           0.470588
# 3                             1.0           0.384615
# 4                             1.0           1.000000

# %%
# Basic information about selected columns
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8558 entries, 0 to 8557
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Late_Applicant                  8558 non-null   int64
#  1   Opportunity_Popularity          8558 non-null   float64
#  2   Popular_Opportunity             8558 non-null   int64
#  3   Age_Major_Combo                 8558 non-null   object
#  4   Country_Gender                  8558 non-null   object
#  5   Region_Opportunity              8558 non-null   object
#  6   Engagement_Score                8558 non-null   float64
#  7   Engagement_Level                8558 non-null   object
#  8   Apply_vs_Start_Gap              8558 non-null   int64
#  9   Applications_per_User           8558 non-null   int64
#  10  Unique_Categories_per_User      8558 non-null   int64
#  11  Region_AgeGroup                 8558 non-null   object
#  12  Applications_for_Opportunity    8558 non-null   int64
#  13  Region_Normalized_Applications  8558 non-null   float64
#  14  User_Success_Rate               8558 non-null   float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 1003.0+ KB

# %%
# Summary statistics
df_selected.describe(include='all').T
# Out:
#                                  count unique                        top  \
# Late_Applicant                  8558.0    NaN                        NaN
# Opportunity_Popularity          8558.0    NaN                        NaN
# Popular_Opportunity             8558.0    NaN                        NaN
# Age_Major_Combo                   8558     20           Young_Adult_Tech
# Country_Gender                    8558    118         United States_Male
# Region_Opportunity                8558     23   North_America_Internship
# Engagement_Score                8558.0    NaN                        NaN
# Engagement_Level                  8558      3                       High
# Apply_vs_Start_Gap              8558.0    NaN                        NaN
# Applications_per_User           8558.0    NaN                        NaN
# Unique_Categories_per_User      8558.0    NaN                        NaN
# Region_AgeGroup                   8558     24  North_America_Young_Adult
# Applications_for_Opportunity    8558.0    NaN                        NaN
# Region_Normalized_Applications  8558.0    NaN                        NaN
# User_Success_Rate               8558.0    NaN                        NaN
#
#                                 freq        mean         std       min  \
# Late_Applicant                   NaN    0.389694    0.487709       0.0
# Opportunity_Popularity           NaN         0.0    1.000058 -1.745423
# Popular_Opportunity              NaN    0.470086    0.499134       0.0
# Age_Major_Combo                 3680         NaN         NaN       NaN
# Country_Gender                  2203         NaN         NaN       NaN
# Region_Opportunity              2802         NaN         NaN       NaN
# Engagement_Score                 NaN    0.473966    0.308631       0.0
# Engagement_Level                3835         NaN         NaN       NaN
# Apply_vs_Start_Gap               NaN  -22.717691  291.014019    -998.0
# Applications_per_User            NaN    8.332087   10.482562       1.0
# Unique_Categories_per_User       NaN    2.248189    1.256366       1.0
# Region_AgeGroup                 2352         NaN         NaN       NaN
# Applications_for_Opportunity     NaN  705.873802  404.966107       4.0
# Region_Normalized_Applications   NaN    0.492136    0.286752       0.0
# User_Success_Rate                NaN    0.475812    0.336048       0.0
#
#                                      25%       50%       75%       max
# Late_Applicant                       0.0       0.0       1.0       1.0
# Opportunity_Popularity         -0.715572 -0.368152  0.676589  1.775924
# Popular_Opportunity                  0.0       0.0       1.0       1.0
# Age_Major_Combo                      NaN       NaN       NaN       NaN
# Country_Gender                       NaN       NaN       NaN       NaN
# Region_Opportunity                   NaN       NaN       NaN       NaN
# Engagement_Score                     0.2       0.4      0.65       1.0
# Engagement_Level                     NaN       NaN       NaN       NaN
# Apply_vs_Start_Gap                -181.0       1.0     189.0     570.0
# Applications_per_User                2.0       5.0      11.0      83.0
# Unique_Categories_per_User           1.0       2.0       3.0       5.0
# Region_AgeGroup                      NaN       NaN       NaN       NaN
# Applications_for_Opportunity       419.0     559.0     980.0    1423.0
# Region_Normalized_Applications  0.292459  0.391121  0.687808       1.0
# User_Success_Rate               0.222222  0.493976  0.692308       1.0

# %%
# Check missing values
df_selected.isnull().sum()
# Out:
# Late_Applicant                    0
# Opportunity_Popularity            0
# Popular_Opportunity               0
# Age_Major_Combo                   0
# Country_Gender                    0
# Region_Opportunity                0
# Engagement_Score                  0
# Engagement_Level                  0
# Apply_vs_Start_Gap                0
# Applications_per_User             0
# Unique_Categories_per_User        0
# Region_AgeGroup                   0
# Applications_for_Opportunity      0
# Region_Normalized_Applications    0
# User_Success_Rate                 0
# dtype: int64

# %%
# Correlation heatmap (numeric columns only)
numeric_df = df_selected.select_dtypes(include=['int64', 'float64'])

if not numeric_df.empty:
    plt.figure(figsize=(12,8))
    sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
    plt.title("Correlation Heatmap (Columns 33-47)")
    plt.show()
else:
    print("No numeric columns available for correlation heatmap.")

# %%
# Distribution plots for numerical columns
num_cols = df_selected.select_dtypes(include=['float64','int64']).columns

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df_selected[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
# Countplots for categorical columns
cat_cols = df_selected.select_dtypes(include=['object']).columns

for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df_selected, x=col)
    plt.title(f"Countplot of {col}")
    plt.xticks(rotation=55)
    plt.show()
